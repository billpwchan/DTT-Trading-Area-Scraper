# %%
import json

input1 = json.load(open('Input1.json', 'r', encoding='UTF-8'))
input2 = json.load(open('Input2.json', 'r', encoding='UTF-8'))
input3 = json.load(open('Input3.json', 'r', encoding='UTF-8'))
input4 = json.load(open('Input4.json', 'r', encoding='UTF-8'))
input = json.load(open('Input4.json', 'r', encoding='UTF-8'))
input4 = json.load(open('Input4.json', 'r', encoding='UTF-8'))


print(input1[0])
print(input2[0])
print(input3[0])
print(input4[0])
# Out:
# {'district': '闵行区', 'type': '4-优质商圈', 'centerlnglat': '121.4271324834166,31.01785421011887', 'trading_area': '老闵行', 'GaodengyuanxiaoNum': 14}
# {'district': '闵行区', 'type': '4-优质商圈', 'centerlnglat': '121.4271324834166,31.01785421011887', 'trading_area': '老闵行', 'SimilarShop': 17}
# {'district': '闵行区', 'type': '4-优质商圈', 'lng': 121.4271324834166, 'lat': 31.01785421011887, 'trading_area': '老闵行', 'PeopleNumber': '10022'}
# {'district': '闵行区', 'type': '4-优质商圈', 'centerlnglat': '121.4271324834166,31.01785421011887', 'trading_area': '老闵行', 'SubwayNum': 22, 'BusStationNum': 150}

# %%
parsed_list = []
for i in range(len(input1)):
    item = {}
    item['district'] = input1[i]['district']
    item['type'] = input1[i]['type']
    item['lng'] = input3[i]['lng']
    item['lat'] = input3[i]['lat']
    item['trading_area'] = input1[i]['trading_area']
    item['school_num'] = input1[i]['GaodengyuanxiaoNum']
    item['similar_shops_num'] = input2[i]['SimilarShop']
    item['human_traffic'] = input3[i]['PeopleNumber']
    item['subway_num'] = input4[i]['SubwayNum']
    item['bus_station_num'] = input4[i]['BusStationNum']
    parsed_list.append(item)

# %%
parsed_list[0]
# Out:
# {'district': '闵行区',
#  'type': '4-优质商圈',
#  'lng': 121.4271324834166,
#  'lat': 31.01785421011887,
#  'trading_area': '老闵行',
#  'school_num': 14,
#  'similar_shops_num': 17,
#  'human_traffic': '10022',
#  'subway_num': 22,
#  'bus_station_num': 150}

# %%
import pandas as pd

trading_area = pd.DataFrame(parsed_list)
trading_area[['lng', 'lat', 'school_num', 'similar_shops_num', 'human_traffic', 'subway_num', 'bus_station_num']] = trading_area[['lng', 'lat', 'school_num', 'similar_shops_num', 'human_traffic', 'subway_num', 'bus_station_num']].apply(pd.to_numeric)
trading_area.head()
# Out:
#   district    type         lng        lat trading_area  school_num  \
# 0      闵行区  4-优质商圈  121.427132  31.017854          老闵行          14
# 1      闵行区  2-普通商圈  121.405506  31.151684           古美         100
# 2      闵行区  4-优质商圈  121.321672  31.223513           华漕         120
# 3      闵行区  4-优质商圈  121.412374  31.111444           春申         120
# 4      闵行区  4-优质商圈  121.373234  31.185905           龙柏          29
#
#    similar_shops_num  human_traffic  subway_num  bus_station_num
# 0                 17          10022          22              150
# 1                 57           1966          96              280
# 2                 23          15236          19              117
# 3                 76          13070          59              198
# 4                 44          13079          63              242

# %%
types = trading_area.type.unique().tolist()

# %%
trading_area[trading_area['type'] == '4-优质商圈']
# Out:
#     district    type         lng        lat trading_area  school_num  \
# 0        闵行区  4-优质商圈  121.427132  31.017854          老闵行          14
# 2        闵行区  4-优质商圈  121.321672  31.223513           华漕         120
# 3        闵行区  4-优质商圈  121.412374  31.111444           春申         120
# 4        闵行区  4-优质商圈  121.373234  31.185905           龙柏          29
# 6        闵行区  4-优质商圈  121.472955  31.051409           吴泾          11
# ..       ...     ...         ...        ...          ...         ...
# 227      朝阳区  4-优质商圈  125.332313  43.894627         人民广场          30
# 228      黄浦区  4-优质商圈  121.502863  31.249239           外滩          48
# 229      静安区  4-优质商圈  121.460989  31.239188          新闸路          70
# 234      黄浦区  4-优质商圈  121.498706  31.211954         蓬莱公园          44
# 237      黄浦区  4-优质商圈  121.497408  31.232098           豫园          47
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num
# 0                   17          10022          22              150
# 2                   23          15236          19              117
# 3                   76          13070          59              198
# 4                   44          13079          63              242
# 6                   13          12287         140               88
# ..                 ...            ...         ...              ...
# 227                 80           1393          84              280
# 228                 80           5844         130              280
# 229                 80           4443         140              280
# 234                 80           2330         127              280
# 237                 80           4443         140              280
#
# [98 rows x 10 columns]

# %%
trading_area['school_num_rank'] = trading_area['school_num'].rank(ascending=False)
trading_area['similar_shops_num_rank'] = trading_area['similar_shops_num'].rank(ascending=False)
trading_area['human_traffic_rank'] = trading_area['human_traffic'].rank(ascending=False)
trading_area['subway_num_rank'] = trading_area['subway_num'].rank(ascending=False)
trading_area['bus_station_num_rank'] = trading_area['bus_station_num'].rank(ascending=False)

trading_area.head()
# Out:
#   district    type         lng        lat trading_area  school_num  \
# 0      闵行区  4-优质商圈  121.427132  31.017854          老闵行          14
# 1      闵行区  2-普通商圈  121.405506  31.151684           古美         100
# 2      闵行区  4-优质商圈  121.321672  31.223513           华漕         120
# 3      闵行区  4-优质商圈  121.412374  31.111444           春申         120
# 4      闵行区  4-优质商圈  121.373234  31.185905           龙柏          29
#
#    similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 0                 17          10022          22              150
# 1                 57           1966          96              280
# 2                 23          15236          19              117
# 3                 76          13070          59              198
# 4                 44          13079          63              242
#
#    school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 0            226.0                   220.0                37.5
# 1             87.0                   155.5               173.5
# 2             41.0                   214.0                11.0
# 3             41.0                   132.5                22.0
# 4            190.0                   178.0                20.0
#
#    subway_num_rank  bus_station_num_rank
# 0            225.0                 197.5
# 1            145.0                  39.0
# 2            228.0                 214.0
# 3            196.0                 164.0
# 4            187.5                 114.5

# %%
trading_area['total_score'] = trading_area['school_num_rank'] + trading_area['similar_shops_num_rank'] + trading_area['human_traffic_rank'] + trading_area['subway_num_rank'] + trading_area['bus_station_num_rank']

trading_area[trading_area['type'] == '4-优质商圈'].sort_values('total_score').head(10)
# Out:
#     district    type         lng        lat trading_area  school_num  \
# 177      徐汇区  4-优质商圈  121.450445  31.208216          衡山路         120
# 131      长宁区  4-优质商圈  121.431561  31.211794         上海影城         120
# 171      徐汇区  4-优质商圈  121.448473  31.201154          徐家汇         120
# 162      徐汇区  4-优质商圈  121.460718  31.201942          枫林路         120
# 184      徐汇区  4-优质商圈  121.458388  31.203540         肇嘉浜路         120
# 211      静安区  4-优质商圈  121.450998  31.240706          同乐坊          71
# 73       卢湾区  4-优质商圈  121.472914  31.216425        瑞金宾馆区         100
# 167      徐汇区  4-优质商圈  121.425846  31.175316           田林         120
# 43       普陀区  4-优质商圈  121.442917  31.245662          长寿路          64
# 74       卢湾区  4-优质商圈  121.480428  31.224615          新天地          67
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 177                 80           9321         140              280
# 131                 80           9267         140              280
# 171                 80          16877         140              257
# 162                 80           5051         140              280
# 184                 80           5051         140              280
# 211                 80           9513         140              280
# 73                  80           6063         140              280
# 167                 80          11554         140              222
# 43                  80           9440         140              280
# 74                  80           6063         140              280
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 177             41.0                    63.0                48.0
# 131             41.0                    63.0                50.0
# 171             41.0                    63.0                 9.0
# 162             41.0                    63.0                86.5
# 184             41.0                    63.0                86.5
# 211            115.0                    63.0                41.0
# 73              87.0                    63.0                70.0
# 167             41.0                    63.0                27.5
# 43             125.5                    63.0                45.5
# 74             120.0                    63.0                70.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 177             47.5                  39.0        238.5
# 131             47.5                  39.0        240.5
# 171             47.5                 101.5        262.0
# 162             47.5                  39.0        277.0
# 184             47.5                  39.0        277.0
# 211             47.5                  39.0        305.5
# 73              47.5                  39.0        306.5
# 167             47.5                 130.0        309.0
# 43              47.5                  39.0        320.5
# 74              47.5                  39.0        339.5

# %%
trading_area_cbd = trading_area[trading_area['type'] == '4-优质商圈']

for i in range(trading_area_cbd['human_traffic'].min(), trading_area_cbd['human_traffic'].max(), 1000):
    for j in range(trading_area_cbd['subway_num'].min(), trading_area_cbd['subway_num'].max()):
        if (trading_area_cbd[(trading_area_cbd['human_traffic'] > i) & (trading_area_cbd['subway_num'] > j)]['trading_area'].count() <= 10):
            print(f'Human Traffic: {i}, Subway Num: {j} ')
            print('Number of Record: %d', trading_area_cbd[(trading_area_cbd['human_traffic'] > i) & (trading_area_cbd['subway_num'] > j)]['trading_area'].count())
            print(trading_area_cbd[(trading_area_cbd['human_traffic'] > i) & (trading_area_cbd['subway_num'] > j)])
            break
# Out:
# Human Traffic: 10177, Subway Num: 123
# Number of Record: %d 10
#     district    type         lng        lat trading_area  school_num  \
# 6        闵行区  4-优质商圈  121.472955  31.051409           吴泾          11
# 45       普陀区  4-优质商圈  121.407679  31.237055          华师大          55
# 134      长宁区  4-优质商圈  121.405333  31.217846          天山路          80
# 161      徐汇区  4-优质商圈  121.453648  31.123636           华泾         120
# 163      徐汇区  4-优质商圈  121.456178  31.180792           龙华          65
# 166      徐汇区  4-优质商圈  121.426358  31.168614         上海师大         120
# 167      徐汇区  4-优质商圈  121.425846  31.175316           田林         120
# 168      徐汇区  4-优质商圈  121.445501  31.191115          万体馆         100
# 171      徐汇区  4-优质商圈  121.448473  31.201154          徐家汇         120
# 174      徐汇区  4-优质商圈  121.426566  31.174168          漕河泾         100
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 6                   13          12287         140               88
# 45                  80          13488         131              280
# 134                 80          12828         124              214
# 161                 11          10911         140              114
# 163                 80          13751         140              182
# 166                 57          11554         140              197
# 167                 80          11554         140              222
# 168                 80          11554         140              226
# 171                 80          16877         140              257
# 174                 80          11554         140              214
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
#
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 129      长宁区  4-优质商圈  121.405683  31.205612           古北         100
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
# 171      徐汇区  4-优质商圈  121.448473  31.201154          徐家汇         120
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 2                   23          15236          19              117
# 7                   72          15982          53              203
# 8                   47          18036          80              280
# 128                 63          21810         105              161
# 129                 80          18762          97              209
# 130                 34          19949          57              160
# 171                 80          16877         140              257
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 2               41.0                   214.0                11.0
# 7              179.5                   135.0                10.0
# 8              133.0                   173.0                 6.0
# 128             41.0                   148.5                 2.0
# 129             87.0                    63.0                 4.0
# 130            196.0                   195.0                 3.0
# 171             41.0                    63.0                 9.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 2              228.0                 214.0        708.0
# 7              203.0                 158.0        685.5
# 8              165.5                  39.0        516.5
# 128            133.0                 187.0        511.5
# 129            143.5                 149.0        446.5
# 130            198.0                 189.5        781.5
# 171             47.5                 101.5        262.0
# Human Traffic: 16177, Subway Num: 13
# Number of Record: %d 5
#     district    type         lng        lat trading_area  school_num  \
# 8        闵行区  4-优质商圈  121.406147  31.137905         南方商城          60
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 129      长宁区  4-优质商圈  121.405683  31.205612           古北         100
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
# 171      徐汇区  4-优质商圈  121.448473  31.201154          徐家汇         120
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 8                   47          18036          80              280
# 128                 63          21810         105              161
# 129                 80          18762          97              209
# 130                 34          19949          57              160
# 171                 80          16877         140              257
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 8              133.0                   173.0                 6.0
# 128             41.0                   148.5                 2.0
# 129             87.0                    63.0                 4.0
# 130            196.0                   195.0                 3.0
# 171             41.0                    63.0                 9.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 8              165.5                  39.0        516.5
# 128            133.0                 187.0        511.5
# 129            143.5                 149.0        446.5
# 130            198.0                 189.5        781.5
# 171             47.5                 101.5        262.0
# Human Traffic: 17177, Subway Num: 13
# Number of Record: %d 4
#     district    type         lng        lat trading_area  school_num  \
# 8        闵行区  4-优质商圈  121.406147  31.137905         南方商城          60
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 129      长宁区  4-优质商圈  121.405683  31.205612           古北         100
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 8                   47          18036          80              280
# 128                 63          21810         105              161
# 129                 80          18762          97              209
# 130                 34          19949          57              160
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 8              133.0                   173.0                 6.0
# 128             41.0                   148.5                 2.0
# 129             87.0                    63.0                 4.0
# 130            196.0                   195.0                 3.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 8              165.5                  39.0        516.5
# 128            133.0                 187.0        511.5
# 129            143.5                 149.0        446.5
# 130            198.0                 189.5        781.5
# Human Traffic: 18177, Subway Num: 13
# Number of Record: %d 3
#     district    type         lng        lat trading_area  school_num  \
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 129      长宁区  4-优质商圈  121.405683  31.205612           古北         100
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 128                 63          21810         105              161
# 129                 80          18762          97              209
# 130                 34          19949          57              160
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 128             41.0                   148.5                 2.0
# 129             87.0                    63.0                 4.0
# 130            196.0                   195.0                 3.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 128            133.0                 187.0        511.5
# 129            143.5                 149.0        446.5
# 130            198.0                 189.5        781.5
# Human Traffic: 19177, Subway Num: 13
# Number of Record: %d 2
#     district    type         lng        lat trading_area  school_num  \
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 128                 63          21810         105              161
# 130                 34          19949          57              160
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 128             41.0                   148.5                 2.0
# 130            196.0                   195.0                 3.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 128            133.0                 187.0        511.5
# 130            198.0                 189.5        781.5
# Human Traffic: 20177, Subway Num: 13
# Number of Record: %d 1
#     district    type         lng        lat trading_area  school_num  \
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 128                 63          21810         105              161
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 128             41.0                   148.5                 2.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 128            133.0                 187.0        511.5
# Human Traffic: 21177, Subway Num: 13
# Number of Record: %d 1
#     district    type         lng        lat trading_area  school_num  \
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 128                 63          21810         105              161
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 128             41.0                   148.5                 2.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 128            133.0                 187.0        511.5

# %%
trading_area_cbd = trading_area[trading_area['type'] == '4-优质商圈']

for i in range(trading_area_cbd['human_traffic'].min(), trading_area_cbd['human_traffic'].max(), 1000):
    if (trading_area_cbd[(trading_area_cbd['human_traffic'] > i)]['trading_area'].count() <= 10):
        print(f'Human Traffic: {i}')
        print('Number of Record: %d', trading_area_cbd[(trading_area_cbd['human_traffic'] > i)]['trading_area'].count())
        print(trading_area_cbd[(trading_area_cbd['human_traffic'] > i)])
        break
# Out:
# Human Traffic: 14177
# Number of Record: %d 9
#     district    type         lng        lat trading_area  school_num  \
# 2        闵行区  4-优质商圈  121.321672  31.223513           华漕         120
# 7        闵行区  4-优质商圈  121.358836  31.162632           七宝          34
# 8        闵行区  4-优质商圈  121.406147  31.137905         南方商城          60
# 12       闵行区  4-优质商圈  121.404242  31.076166           颛桥         120
# 55       普陀区  4-优质商圈  121.393064  31.250517           长征          27
# 128      西城区  4-优质商圈  116.357165  39.947103          动物园         120
# 129      长宁区  4-优质商圈  121.405683  31.205612           古北         100
# 130      长宁区  4-优质商圈  121.369700  31.199321         虹桥机场          26
# 171      徐汇区  4-优质商圈  121.448473  31.201154          徐家汇         120
#
#      similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 2                   23          15236          19              117
# 7                   72          15982          53              203
# 8                   47          18036          80              280
# 12                  29          18036          13              149
# 55                  76          15089          88              272
# 128                 63          21810         105              161
# 129                 80          18762          97              209
# 130                 34          19949          57              160
# 171                 80          16877         140              257
#
#      school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 2               41.0                   214.0                11.0
# 7              179.5                   135.0                10.0
# 8              133.0                   173.0                 6.0
# 12              41.0                   207.0                 6.0
# 55             193.5                   132.5                12.0
# 128             41.0                   148.5                 2.0
# 129             87.0                    63.0                 4.0
# 130            196.0                   195.0                 3.0
# 171             41.0                    63.0                 9.0
#
#      subway_num_rank  bus_station_num_rank  total_score
# 2              228.0                 214.0        708.0
# 7              203.0                 158.0        685.5
# 8              165.5                  39.0        516.5
# 12             238.0                 199.0        691.0
# 55             153.0                  84.0        575.0
# 128            133.0                 187.0        511.5
# 129            143.5                 149.0        446.5
# 130            198.0                 189.5        781.5
# 171             47.5                 101.5        262.0

# %%
trading_area_cbd[(trading_area_cbd['trading_area'] == '五角场')]
# Out:
#    district    type         lng        lat trading_area  school_num  \
# 32      杨浦区  4-优质商圈  121.518016  31.306363          五角场         120
#
#     similar_shops_num  human_traffic  subway_num  bus_station_num  \
# 32                 80            870          81              265
#
#     school_num_rank  similar_shops_num_rank  human_traffic_rank  \
# 32             41.0                    63.0               217.0
#
#     subway_num_rank  bus_station_num_rank  total_score
# 32            161.5                  92.5        575.0

# %%
trading_area_cbd['district_human_traffic_rank'] = trading_area_cbd.groupby('district')['human_traffic'].rank(ascending=False)
trading_area_cbd = trading_area_cbd.sort_values('district_human_traffic_rank', ascending=False)
top2 = trading_area_cbd.groupby('district').head(2).sort_values('district')
top2[['district', 'trading_area']]
# Out:
#     district trading_area
# 74       卢湾区          新天地
# 78       卢湾区         复兴公园
# 205      嘉定区           南翔
# 202      嘉定区           马陆
# 187      宽城区          火车站
# 184      徐汇区         肇嘉浜路
# 162      徐汇区          枫林路
# 46       普陀区          甘泉路
# 50       普陀区          宜川路
# 227      朝阳区         人民广场
# 33       杨浦区         新江湾城
# 32       杨浦区          五角场
# 66       松江区         松江新城
# 63       松江区        松江大学城
# 218      江东区           白鹤
# 98      浦东新区           张江
# 97      浦东新区           周浦
# 115      玄武区           梅园
# 71       白下区          淮海路
# 157      虹口区           江湾
# 148      虹口区         和平公园
# 128      西城区          动物园
# 133      长宁区         仙霞新村
# 131      长宁区         上海影城
# 10       闵行区           莘庄
# 0        闵行区          老闵行
# 185      闸北区         彭浦新村
# 186      闸北区          老北站
# 208      静安区          静安寺
# 229      静安区          新闸路
# 225      黄浦区         南浦大桥
# 234      黄浦区         蓬莱公园
# 173      鼓楼区          湖南路
